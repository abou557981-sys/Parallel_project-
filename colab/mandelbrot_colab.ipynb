# %% [markdown]
# # Mandelbrot CUDA on Google Colab\nEnable GPU runtime first: **Runtime -> Change runtime type -> GPU**.

# %%
# !nvidia-smi

# %%
# Option A: clone repo\n# !git clone <your-repo-url>\n# %cd Parallel_project-\n\n# Option B: if already in repo path, just run:\n!bash colab/run_in_colab.sh

# %%
# !pip -q install pillow\n!python colab/display_ppm.py --input results/mandelbrot_cuda_colab.ppm --output results/mandelbrot_cuda_colab.png

# %%
from IPython.display import Image, display\ndisplay(Image('results/mandelbrot_cuda_colab.png'))
